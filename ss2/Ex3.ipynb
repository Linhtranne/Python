# %%
num = int(input("Nhập vào một số nguyên: "))
if num % 3 == 0 and num % 5 == 0:
    print("Số chia hết cho cả 3 và 5")
elif num % 3 == 0:
    print("Số chia hết cho 3")
elif num % 5 == 0:
    print("Số chia hết cho 5")
else:
    print("Số không chia hết cho cả 3 và 5")
# Out:
# Số không chia hết cho cả 3 và 5
