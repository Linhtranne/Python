# %%
import pandas as pd
import numpy as np

df3 = pd.DataFrame({
    "name": ["Linh", "Linhh", "Linhhh", "Linhhhh", "Linhhhhh"],
    "age": [20, np.nan, 21, np.nan, 24],
    "score": [7.5, 8.0, 9.0, 6.5, np.nan]
})

na_mask = df3.isna()
age_mean = df3["age"].mean()
df3_filled = df3.copy()
df3_filled["age"] = df3_filled["age"].fillna(age_mean)
df3_dropna = df3.dropna()
