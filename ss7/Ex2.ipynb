# %%
import pandas as pd

df2 = pd.DataFrame({
    "name": ["Linh", "Linhh", "Linhhh", "Linhhhh", "Linhhhhh"],
    "age": [20, 22, 21, 23, 24],
    "score": [7.5, 8.0, 9.0, 6.5, 8.5]
})

df2_loc = df2.loc[df2["score"] >= 8]
df2_iloc_age = df2.iloc[:, 1]
df2_query = df2.query("score > 7 and age < 23")
