# %%
import pandas as pd

df5 = pd.DataFrame({
    "name": ["An", "Bình", "Chi", "Dũng", "Hoa", "Khanh"],
    "age": [20, 22, 20, 23, 22, 20],
    "score": [7.5, 8.0, 9.0, 6.5, 8.5, 7.0]
})

grouped = df5.groupby("age")["score"].agg(["mean", "min", "max"])
