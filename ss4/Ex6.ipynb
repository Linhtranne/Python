# %%
student = {
    "name" : "Lan",
    "scores" :  {
        "math": 9,
        "english": 8,
        "history": 7
    }
}
print(student["scores"]["english"])
avgscore = (student["scores"]["math"] + student["scores"]["english"] + student["scores"]["history"]) / 3
print("Điểm trung bình:", avgscore)
# Out:
# 8
# Điểm trung bình: 8.0
