# %%
products = { "A":120  , "B": 80, "C": 300 , "D": 50  }
products = {k: v for k, v in products.items() if v >= 100}
print("Danh sách sản phẩm còn lại:", products)
products["E"] = 200
print("Danh sách sản phẩm sau khi thêm:", products)
print("Số lượng sản phẩm còn lại:", len(products))
# Out:
# Danh sách sản phẩm còn lại: {'A': 120, 'C': 300}
# Danh sách sản phẩm sau khi thêm: {'A': 120, 'C': 300, 'E': 200}
# Số lượng sản phẩm còn lại: 3
