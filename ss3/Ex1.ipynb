# %%
def isTriange(a, b, c):
    if a + b > c and a + c > b and b + c > a:
        return print("Là tam giác")
    else:
        return print("Không là tam giác")
isTriange(int(input()), int(input()), int(input()))
# Out:
# Là tam giác
