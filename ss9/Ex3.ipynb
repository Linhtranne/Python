# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 20)
y = 2 * x + 3
fig, ax = plt.subplots()
ax.plot(x, y, color='blue', linewidth=3)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.grid(True)
plt.show()
